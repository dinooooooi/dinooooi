# %% [markdown]
# <a href="https://colab.research.google.com/github/dinooooooi/dinooooi/blob/main/ESAA0915hwcode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

anscombe = sns.load_dataset("anscombe")
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89
# <class 'pandas.core.frame.DataFrame'>

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
dataset_1 = anscombe[anscombe['dataset']=='I']

# %%
plt.plot(dataset_1['x'],dataset_1['y'])
# Out:
# <div id='182080d3-efa8-4ebd-b8df-8c93e6b874fc'></div>

# %%
plt.plot(dataset_1['x'], dataset_1['y'], 'o')

# %%
dataset_2 = anscombe[anscombe['dataset']=='II']
dataset_3 = anscombe[anscombe['dataset']=='III']
dataset_4 = anscombe[anscombe['dataset']=='IV']

# %%
fig = plt.figure()
# Out:
# <div id='8f416d57-8ea6-4043-a238-f2f238e4ec9d'></div>

# %%
axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

# %%
axes1.plot(dataset_1['x'], dataset_1['y'], 'o')
axes2.plot(dataset_2['x'], dataset_2['y'], 'o')
axes3.plot(dataset_3['x'], dataset_3['y'], 'o')
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

# %%
axes1.set_title("dataset_1")
axes2.set_title("dataset_2")
axes3.set_title("dataset_3")
axes4.set_title("dataset_4")
# Out:
# Text(0.5, 1.0, 'dataset_4')

# %%
fig.suptitle("Anscombe Data")
# Out:
# Text(0.5, 0.98, 'Anscombe Data')

# %%
fig.tight_layout()

# %%
tips = sns.load_dataset("tips")
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %%
fig = plt.figure()
axes1 = fig.add_subplot(1,1,1)
# Out:
# <div id='c94a0162-3f83-438c-8126-0c2fe0c84fa7'></div>

# %%
axes1.hist(tips['total_bill'], bins=10)
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_label('Total Bill')

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'], tips['tip'])
axes1.set_title('scatterplot of total bill vs tips')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# <div id='4042e2c5-3699-4980-ab48-5770a2b5177e'></div>
# Text(0, 0.5, 'Tip')

# %%
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1,1,1)
axes1.boxplot([tips[tips['sex']=='Female']['tip'],
               tips[tips['sex']=='Male']['tip']],
              labels=['Female', 'Male'])
axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# <div id='153fc6e0-03c5-4a3b-a164-8ff3b951fa39'></div>
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %%
def recode_sex(sex):
    if sex == 'Female':
         return 0
    else:
         return 1

# %%
tips['sex_color'] = tips['sex'].apply(recode_sex)

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(
    x=tips['total_bill'],
    y=tips['tip'],
    s=tips['size']*10,
    c=tips['sex_color'],
    alpha=0.5)
axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# <div id='d68dc93c-fcd9-4bcc-b35d-13d58510be52'></div>
# Text(0, 0.5, 'Tip')

# %%
import seaborn as sns
tips = sns.load_dataset("tips")

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'])
ax.set_title('Total Bill Histogram with Density Plot')
# Out:
# <div id='8a76729f-6ff3-4cb8-8985-faed111e5745'></div>
# <ipython-input-36-071bdf8959b6>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'])
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], kde=False)
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# <div id='1db61dc8-e4ec-4011-8bed-00890776d1b9'></div>
# <ipython-input-35-29ef41561e71>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], kde=False)
# Text(0, 0.5, 'Frequency')

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], hist=False)
ax.set_title('Total Bill Density')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Unit Probabillity')
# Out:
# <div id='a06529e2-c4a3-4ca5-906d-c7f5a63a9b0b'></div>
# <ipython-input-37-647c01f18778>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], hist=False)
# Text(0, 0.5, 'Unit Probabillity')

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], rug=True)
ax.set_title('total bill histogram with density and rug plot')
ax.set_xlabel('total bill')
# Out:
# <div id='3f8ea1e7-39b0-401c-bbec-2d8871655063'></div>
# <ipython-input-39-3026648990e4>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], rug=True)
# Text(0.5, 0, 'total bill')

# %%
ax = plt.subplots()
ax = sns.countplot('day', data=tips)
ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')
# Out:
# <div id='3725b06a-9b06-4d80-9062-32f3da23edf3'></div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-a09c9f906068> in <cell line: 2>()
#       1 ax = plt.subplots()
# ----> 2 ax = sns.countplot('day', data=tips)
#       3 ax.set_title('Count of days')
#       4 ax.set_xlabel('Day of the Week')
#       5 ax.set_ylabel('Frequency')
#
# TypeError: countplot() got multiple values for argument 'data'

# %%
ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip', data=tips)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# <div id='a8d5cf83-7db9-4829-afb1-b230dad46136'></div>
# Text(0, 0.5, 'Tip')

# %%
ax = plt.subplots()
ax=sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=False)
ax.set_title('Scatterplot of total bill and tip')
ax.set_xlabel('total bill')
ax.set_ylabel('tip')
# Out:
# <ipython-input-45-043026d1a503>:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   ax = plt.subplots()
# <div id='2b9c7573-8e4f-4a7f-bfff-0649588f2b39'></div>
# Text(0, 0.5, 'tip')

# %%
joint = sns.jointplot(x='total_bill', y='tip', data=tips)
joint.set_axis_labels(xlabel='total bill', ylabel='tip')
joint.fig.suptitle('Joint plot of total bill and tip', fontsize=10, y=1.03)
# Out:
# <div id='856bf6a1-643b-4ea9-ab97-98d5efbc80e7'></div>
# Text(0.5, 1.03, 'Joint plot of total bill and tip')

# %%
hexbin = sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex")
hexbin.set_axis_labels(xlabel='Totalbill', ylabel='Tip')
hexbin.fig.suptitle('Hexbin Joint Plot of total bill and tip', fontsize=10, y=1.03)
# Out:
# <div id='52bedd8b-9d13-41c9-9f63-a02269fd54d9'></div>
# Text(0.5, 1.03, 'Hexbin Joint Plot of total bill and tip')

# %%
ax = plt.subplots()
ax = sns,kdeplot(data=tips['total_bill'],
                 data2=tips['tip'],
                 shade=True)
ax.set_title('kernel density plot of total bill and tip')
ax.set_xlabel('total bill')
ax.set_ylabel('tip')
# Out:
# <div id='fef14ec3-3d7f-4cc3-8403-28814b84f3f0'></div>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-306cfbab6f63> in <cell line: 2>()
#       1 ax = plt.subplots()
# ----> 2 ax = sns,kdeplot(data=tips['total_bill'],
#       3                  data2=tips['tip'],
#       4                  shade=True)
#       5 ax.set_title('kernel density plot of total bill and tip')
#
# NameError: name 'kdeplot' is not defined

# %%
ax = plt.subplots()
ax = sns.barplot(x='time', y='total_bill', data=tips)
ax.set_title('bar plot of average total vill for time of day')
ax.set_xlabel('time of day')
ax.set_ylabel('average total bill')
# Out:
# <div id='d8768d30-914a-455f-9a31-55539775280f'></div>
# Text(0, 0.5, 'average total bill')

# %%
ax = plt.subplots()
ax = sns.boxplot(x='time', y= 'total_bill', data=tips)
ax.set_title('boxplot of total bill by time of day')
ax.set_xlabel('time of day')
ax.set_ylabel('total bill')
# Out:
# <div id='53d73ee4-3f62-4f2a-9d82-ab0e734c6169'></div>
# Text(0, 0.5, 'total bill')

# %%
ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', data=tips)
ax.set_title('violin plot of total bill by time of day')
ax.set_xlabel('time of day')
ax.set_ylabel('total bill')
# Out:
# <div id='98840182-3ca9-4881-9e5c-7f4a1e04d3a3'></div>
# Text(0, 0.5, 'total bill')

# %%
fig = sns.pairplot(tips)
# Out:
# <div id='0d0cb6a9-6c29-47d4-a60a-705666d0e310'></div>

# %%
pair_grid = sns.PairGrid(tips)
pair_grid = pair_grid.map_upper(sns.regplot)
pair_grid = pair_grid.map_lower(sns.kdeplot)
pair_grid = pair_grid.map_diag(sns.displot, rug=True)
plt.show()
# Out:
# <div id='e875e29f-4af6-42ec-a51a-7394b8b6024a'></div>
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# <div id='147b6da3-7e54-4b4d-8373-a862313a0c12'></div>
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# <div id='36f2f8c5-81bf-411f-a04b-6376a1c0ab34'></div>
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# <div id='5b96f4b8-c011-4072-98f6-068a8d50d346'></div>

# %%
ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)
# Out:
# <div id='688475ca-0065-4a08-bf88-75e690c5f50c'></div>

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', fir_reg=False)

# %%
fig=sns.pairplot(tips,hue='sex')
# Out:
# <div id='78597c94-b4e2-4cfe-8487-6d70334e5dfd'></div>

# %%
scatter = sns.lmplot(x='total_bill', y='tip',data=tips, fit_reg=False, hue='sex',
                     scatter_kws={'s': tips['size']*10})
# Out:
# <div id='51b3554a-05e4-4728-9139-c10b71860488'></div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-e37bed9956d0> in <cell line: 1>()
# ----> 1 scatter = sns.lmplot(x='total_bill', y='tip',data=tips, fit_reg=False, hue='sex',
#       2                      scatter_kws={'s': tips['size']*10})
#
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     633         scatter_kws=scatter_kws, line_kws=line_kws,
#     634     )
# --> 635     facets.map_dataframe(regplot, x=x, y=y, **regplot_kws)
#     636     facets.set_axis_labels(x, y)
#     637
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     817
#     818             # Draw the plot
# --> 819             self._facet_plot(func, ax, args, kwargs)
#     820
#     821         # For axis labels, prefer to use positional args for backcompat
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     846             plot_args = []
#     847             plot_kwargs["ax"] = ax
# --> 848         func(*plot_args, **plot_kwargs)
#     849
#     850         # Sort out the supporting information
#
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     757     scatter_kws["marker"] = marker
#     758     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 759     plotter.plot(ax, scatter_kws, line_kws)
#     760     return ax
#     761
#
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py in plot(self, ax, scatter_kws, line_kws)
#     363         # Draw the constituent plots
#     364         if self.scatter:
# --> 365             self.scatterplot(ax, scatter_kws)
#     366
#     367         if self.fit_reg:
#
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py in scatterplot(self, ax, kws)
#     393
#     394             x, y = self.scatter_data
# --> 395             ax.scatter(x, y, **kws)
#     396         else:
#     397             # TODO abstraction
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4591                 (not np.issubdtype(s.dtype, np.floating) and
#    4592                  not np.issubdtype(s.dtype, np.integer))):
# -> 4593             raise ValueError(
#    4594                 "s must be a scalar, "
#    4595                 "or float array-like with the same size as x and y")
#
# ValueError: s must be a scalar, or float array-like with the same size as x and y

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex',
                     markers=['o','x'], scatter_kws={'s':tips['size']*10})
# Out:
# <div id='8755b106-ecd8-49c0-b86e-68ae17bc3835'></div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-17e7664fad18> in <cell line: 1>()
# ----> 1 scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex',
#       2                      markers=['o','x'], scatter_kws={'s':tips['size']*10})
#
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     633         scatter_kws=scatter_kws, line_kws=line_kws,
#     634     )
# --> 635     facets.map_dataframe(regplot, x=x, y=y, **regplot_kws)
#     636     facets.set_axis_labels(x, y)
#     637
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     817
#     818             # Draw the plot
# --> 819             self._facet_plot(func, ax, args, kwargs)
#     820
#     821         # For axis labels, prefer to use positional args for backcompat
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     846             plot_args = []
#     847             plot_kwargs["ax"] = ax
# --> 848         func(*plot_args, **plot_kwargs)
#     849
#     850         # Sort out the supporting information
#
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     757     scatter_kws["marker"] = marker
#     758     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 759     plotter.plot(ax, scatter_kws, line_kws)
#     760     return ax
#     761
#
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py in plot(self, ax, scatter_kws, line_kws)
#     363         # Draw the constituent plots
#     364         if self.scatter:
# --> 365             self.scatterplot(ax, scatter_kws)
#     366
#     367         if self.fit_reg:
#
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py in scatterplot(self, ax, kws)
#     393
#     394             x, y = self.scatter_data
# --> 395             ax.scatter(x, y, **kws)
#     396         else:
#     397             # TODO abstraction
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4591                 (not np.issubdtype(s.dtype, np.floating) and
#    4592                  not np.issubdtype(s.dtype, np.integer))):
# -> 4593             raise ValueError(
#    4594                 "s must be a scalar, "
#    4595                 "or float array-like with the same size as x and y")
#
# ValueError: s must be a scalar, or float array-like with the same size as x and y

# %%
anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False)
# Out:
# <div id='530e605e-a8cb-4db7-9414-24f02f731d92'></div>

# %%
anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False,
                           col='dataset', col_wrap=2)
# Out:
# <div id='fec33bb3-1e89-4727-9318-c83e538c0088'></div>

# %%
facet = sns.FacetGrid(tips, col='time')
facet.map(sns.displot, 'total_bill', rug=True)
# Out:
# <div id='ae509c30-b4be-44f2-9281-e79d57c67908'></div>
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# <div id='afe24040-e3e8-426e-a57c-ca7b90ae7a02'></div>
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# <div id='c8672406-f95e-4b81-b01a-fca35b81447e'></div>

# %%
facet = sns.FacetGrid(tips, col='day', hue='sex')
facet = facet.map(plt.scatter, 'total_bill', 'tip')
facet = facet.add_legend()
# Out:
# <div id='1e3c46d3-2c50-44cb-a7e8-9df51889de31'></div>

# %%
facet = sns.FacetGrid(tips, col='time', row='smoker', hue='sex')
facet.map(plt.scatter, 'total_bill', 'tip')
# Out:
# <div id='32187dd7-d83a-4843-98ba-91efd6ad77e1'></div>

# %%
ax = plt.subplots()
ax = tips['total_bill'].plot.hist()
# Out:
# <div id='3bd3a18e-917e-40e2-acfd-c721a6db74dd'></div>

# %%
fig, ax = plt.subplots()
ax=tips[['total_bill', 'tip']].plot.hist(alpha=0.5, bins=20, ax=ax)
# Out:
# <div id='5bf1b27d-e9a7-493b-9a83-9bf52238ba4f'></div>

# %%
ax = plt.subplots()
ax = tips['tip'].plot.kde()
# Out:
# <div id='929fdc4f-8abd-49bd-aad3-34992ee58c9a'></div>

# %%
fig, ax = plt.subplots( )
ax = tips.plot.scatter(x='total_bill', y='tip', ax=ax)
# Out:
# <div id='53a65de0-221a-49c3-a4c9-368715a6d134'></div>

# %%
fig, ax = plt.subplots( )
ax = tips.plot.hexbin(x='total_bill', y='tip', ax=ax)
# Out:
# <div id='b1961f9c-52f4-4998-9a61-303a0f89e67e'></div>

# %%
fig, ax = plt.subplots( )
ax = tips.plot.hexbin(x='total_bill', y='tip', gridsize=10, ax=ax)
# Out:
# <div id='86e128d7-8a88-4222-ac01-b91389df3e9b'></div>

# %%
fig, ax = plt.subplots( )
ax = tips.plot.box(ax=ax)
# Out:
# <div id='bd7cbeee-dd6c-4020-8ee0-cc48ce3689d7'></div>

# %%
fig, ax = plt.subplots( )
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)
# Out:
# <div id='bba52f61-ba81-4d9e-8628-c719f0dedbce'></div>

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots( )
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)
# Out:
# <div id='36066b89-4f3f-4f05-8989-450ab924f25d'></div>

# %%
fig = plt.figure( )
seaborn_styles = ['darkgrid', 'whitegrid', 'dark', 'white' ,'ticks']
for idx, style in enumerate(seaborn_styles):
    plot_position = idx + 1
    with sns.axes_style(style):
        ax = fig.add_subplot(2, 3, plot_position)
        violin = sns.violinplot(x='time', y='total_bill', data=tips,ax=ax)
        violin.set_title(style)
fig.tight_layout()
# Out:
# <div id='d9e8c63f-f228-46ed-9c9b-5d8fb694565f'></div>
